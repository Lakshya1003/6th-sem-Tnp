# %% [markdown]
# Browser have two parts <br>
# 1. window <br>
# 2. document<br>

# %% [markdown]
# document : whole website or the ui you can observe<br>
# window : the tab bar , search bar and many more is the part of windows

# %% [markdown]
# <span style="color: yellow">The javascript can interact with window + document

# %% [markdown]
# <h1>Queue</h1>

# %% [markdown]
# Types :
# 1. Simple
# 2. Cicular
# 3. Priority
# 4. Double ended queue

# %% [markdown]
# Simple Queue :
# works on FIFO
# EG : Ticket booking system
#
#
# disadvantage :
# 1. poor memory utilization

# %% [markdown]
# Circular queue : (Ring buffer)
#
# end and start are connected
#
# eg : CPU Scheduling

# %% [markdown]
# Double ended queue :
#
# insertion and deletion are possible from start and rear both
#
# eg : sliding window problem

# %% [markdown]
# priority queue : priority based on deque operation
#
# eg : process scheduling

# %% [markdown]
# <h3> Application of Queue </h3>
# 1. Cpu scheduling<br>
# 2. printer queue<br>
# 3. call center system<br>
# 4. graph algorithms<br>
# 5. data buffering<br>
# 6. network queue<br>
# 7. Tree traversal<br>

# %% [markdown]
# <span style="color : pink">
# Why _________________ Queue ?? <br>

# %% [markdown]
# <h2> Operations on Queue </h2>
# <br>
# <h3> Enqueue</h3>
# : Insert value at (rear + 1) % size
#
# <h3> Dequeue</h3>
# : Remove Front Element

# %% [markdown]
# <h2> Conditions to check in Queue </h2>

# %%
class Queue:
    def __init__(self, size):
        self.queue = []
        self.front = -1
        self.rear = -1
        self.size = size

    def is_empty(self):
        return self.front == -1 or self.front > self.rear

    def is_full(self):
        return self.rear == self.size - 1

    def enqueue(self, val):
        if self.is_full():
            print("Queue Overflow")
            return

        if self.front == -1:   # first element insertion
            self.front = 0

        self.rear += 1
        self.queue.append(val)
        print(f"{val} inserted")

    def dequeue(self):
        if self.is_empty():
            print("Queue Underflow")
            return None

        val = self.queue[self.front]
        self.front += 1
        return val

    def display(self):
        if self.is_empty():
            print("Queue is empty")
        else:
            print(self.queue[self.front:self.rear+1])

# %% [markdown]
# <h1> side note</h1>
# <span style="color : red"> we cant provide limitations in functional programing<br>

# %% [markdown]
# <h1> Limitations of queue</h1>
# <br>
# <b>1. Static memory allocation</b>
# <br>
# => If implemented using array , it has a fixed size
# <br>
# => Solution : Use Circular queue or Linked List Based queue
