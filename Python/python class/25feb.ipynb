# %% [markdown]
# <h1>What is Linked List</h1>
#
# => It is a Linear Dynamic Datatype, It is also known as Dynamic array , Mainly Defined on Runtime.<br>
# =>

# %% [markdown]
# <h1>Why Linked List:</h1>
#
# 1. Undifined size
# 2. Hetrogeneous Datatype
# 3. Non - Contigious Memory Allocation (Better memory utilization)

# %% [markdown]
# <h1>When to choose array when to choose Linked List</h1>
#
# <h3>For Array :</h3> When data type is <b>"Known"</b>, when data size is <b>"Known"</b> And data is in <b>Same memory Location</b>
#
# Operations:
# 1. when you want fast searching, it have indexing
# 2. When memory Concern is occured.
#
# <h3>For Linked List :</h3> When these two conditions are not introduced , we use Linked List.
#
# operations:
# 1. when searching is limited, insertion and deletion have large frequency

# %% [markdown]
# <h1> Types of Linked List:</h1>
# <h3>1. Singly Linked List <br> 2. Doubly Linked List <br> 3. Cicular Singly Linked List <br> 4. Circular Doubly Linked List </h3>

# %% [markdown]
# <h1 > Advantage of Linked List </h1>
# <br><h4>
# 1. Efficient Insertion and Deletion.<br>
# 2. Dynamic Size <br>
# 3. No memory Wastage</h4>

# %% [markdown]
# <h1>

# %% [markdown]
# <h1> Disdvantage of Linked List :
# <br></h1><h4>
# 1. Efficient Memory Overhead<br>
# 2. Slower Access</h4>

# %% [markdown]
# <h1>Applications of Linked List</h1>
# <h4>1. Dynamic Memory Allocation.

# %% [markdown]
# <h1>Operations on Linked List : </h1>
#
# <h3>
# 1. Insertion <br>2. Deletion <br> 3. Travesal <br> 4.Searching <br> 5. Reversing</h3>

# %% [markdown]
# <h1>Syntax :

# %%
class Node :
  def __init__(self,data):
    self.data = data
    self.next = None
